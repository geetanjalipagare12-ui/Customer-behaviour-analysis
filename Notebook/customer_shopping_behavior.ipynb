# %%
import pandas as pd
df = pd.read_csv("customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   str
#  3   Item Purchased          3900 non-null   str
#  4   Category                3900 non-null   str
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   str
#  7   Size                    3900 non-null   str
#  8   Color                   3900 non-null   str
#  9   Season                  3900 non-null   str
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   str
#  12  Shipping Type           3900 non-null   str
#  13  Discount Applied        3900 non-null   str
#  14  Promo Code Used         3900 non-null   str
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   str
#  17  Frequency of Purchases  3900 non-null   str
# dtypes: float64(1), int64(4), str(13)
# memory usage: 548.6 KB

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df['review rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# review rating              0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')
df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'review_rating'],
#       dtype='str')

# %%
labels = ['Young', 'Adult','Middle-aged', 'Senior']
df['age_groups'] = pd.qcut(df['age'], q=4, labels=labels)

# %%
df['age_groups']
# Out:
# 0       Middle-aged
# 1             Young
# 2       Middle-aged
# 3             Young
# 4       Middle-aged
#            ...
# 3895          Adult
# 3896    Middle-aged
# 3897    Middle-aged
# 3898          Adult
# 3899    Middle-aged
# Name: age_groups, Length: 3900, dtype: category
# Categories (4, str): ['Young' < 'Adult' < 'Middle-aged' < 'Senior']

# %% [markdown]
# # create column purchase_frequency_days

# %%
frequency_mapping = {
    'Fortnightly':14,
    'Weekly':7,
    'Annually':365,
    'Bi-Weekly': 14,
    'Quarterly': 90,
    'Monthly': 30,
    'Every 3 Months':90
}
df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days', 'frequency_of_purchases']]
# Out:
#       purchase_frequency_days frequency_of_purchases
# 0                          14            Fortnightly
# 1                          14            Fortnightly
# 2                           7                 Weekly
# 3                           7                 Weekly
# 4                         365               Annually
# ...                       ...                    ...
# 3895                        7                 Weekly
# 3896                       14              Bi-Weekly
# 3897                       90              Quarterly
# 3898                        7                 Weekly
# 3899                       90              Quarterly
#
# [3900 rows x 2 columns]

# %%
df['discount_applied'] == df['promo_code_used']
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3895    True
# 3896    True
# 3897    True
# 3898    True
# 3899    True
# Length: 3900, dtype: bool

# %%
df.drop('promo_code_used', inplace = True, axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'review_rating', 'age_groups',
#        'purchase_frequency_days'],
#       dtype='str')

# %%
pip install psycopg2-binary sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: psycopg2-binary in c:\users\bhave\appdata\roaming\python\python314\site-packages (2.9.12)
# Requirement already satisfied: sqlalchemy in c:\users\bhave\appdata\roaming\python\python314\site-packages (2.0.50)
# Requirement already satisfied: greenlet>=1 in c:\users\bhave\appdata\roaming\python\python314\site-packages (from sqlalchemy) (3.5.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\bhave\appdata\roaming\python\python314\site-packages (from sqlalchemy) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine
username = "postgres"
password = "kaveri6352"
host = "localhost"
port = "5432"
database = "customer_behavior"
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

table_name = "customer"
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# ---------------------------------------------------------------------------
# DuplicateColumnError                      Traceback (most recent call last)
# Cell In[18], line 10
#       6 database = "customer_behavior"
#       7 engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")
#       8
#       9 table_name = "customer"
# ---> 10 df.to_sql(table_name, engine, if_exists="replace", index=False)
#      11
#      12 print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3048         3
#    3049         """  # noqa: E501
#    3050         from pandas.io import sql
#    3051
# -> 3052         return sql.to_sql(
#    3053             self,
#    3054             name,
#    3055             con,
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
#     840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#     844         if_exists=if_exists,
#     845         index=index,
#     846         index_label=index_label,
#     847         schema=schema,
#     848         chunksize=chunksize,
#     849         dtype=dtype,
#     850         method=method,
#     851         engine=engine,
#     852         **engine_kwargs,
#     853     )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:2027, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1978 """
#    1979 Write records stored in a DataFrame to a SQL database.
#    1980
#    (...)   2023     Any additional kwargs are passed to the engine.
#    2024 """
#    2025 sql_engine = get_engine(engine)
# -> 2027 table = self.prep_table(
#    2028     frame=frame,
#    2029     name=name,
#    2030     if_exists=if_exists,
#    2031     index=index,
#    2032     index_label=index_label,
#    2033     schema=schema,
#    2034     dtype=dtype,
#    2035 )
#    2037 total_inserted = sql_engine.insert_records(
#    2038     table=table,
#    2039     con=self.con,
#    (...)   2046     **engine_kwargs,
#    2047 )
#    2049 self.check_case_sensitive(name=name, schema=schema)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:1922, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1919         else:
#    1920             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
# -> 1922 table = SQLTable(
#    1923     name,
#    1924     self,
#    1925     frame=frame,
#    1926     index=index,
#    1927     if_exists=if_exists,
#    1928     index_label=index_label,
#    1929     schema=schema,
#    1930     dtype=dtype,
#    1931 )
#    1932 table.create()
#    1933 return table
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:960, in SQLTable.__init__(self, name, pandas_sql_engine, frame, index, if_exists, prefix, index_label, schema, keys, dtype)
#     956 self.dtype = dtype
#     958 if frame is not None:
#     959     # We want to initialize based on a dataframe
# --> 960     self.table = self._create_table_setup()
#     961 else:
#     962     # no data provided, read-only mode
#     963     self.table = self.pd_sql.get_table(self.name, self.schema)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\io\sql.py:1288, in SQLTable._create_table_setup(self)
#    1285 # At this point, attach to new metadata, only attach to self.meta
#    1286 # once table is created.
#    1287 meta = MetaData()
# -> 1288 return Table(self.name, meta, *columns, schema=schema)
#
# File <string>:2, in __new__(cls, *args, **kw)
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\schema.py:430, in Table.__new__(cls, *args, **kw)
#     423 @util.deprecated_params(
#     424     mustexist=(
#     425         "1.4",
#    (...)    428 )
#     429 def __new__(cls, *args: Any, **kw: Any) -> Any:
# --> 430     return cls._new(*args, **kw)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\schema.py:484, in Table._new(cls, *args, **kw)
#     482     return table
#     483 except Exception:
# --> 484     with util.safe_reraise():
#     485         metadata._remove_table(name, schema)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\util\langhelpers.py:122, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     assert exc_value is not None
#     121     self._exc_info = None  # remove potential circular references
# --> 122     raise exc_value.with_traceback(exc_tb)
#     123 else:
#     124     self._exc_info = None  # remove potential circular references
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\schema.py:480, in Table._new(cls, *args, **kw)
#     478 metadata._add_table(name, schema, table)
#     479 try:
# --> 480     table.__init__(name, metadata, *args, _no_init=False, **kw)  # type: ignore[misc] # noqa: E501
#     481     table.dispatch.after_parent_attach(table, metadata)
#     482     return table
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\schema.py:874, in Table.__init__(self, name, metadata, schema, quote, quote_schema, autoload_with, autoload_replace, keep_existing, extend_existing, resolve_fks, include_columns, implicit_returning, comment, info, listeners, prefixes, _extend_on, _no_init, *args, **kw)
#     862     self._autoload(
#     863         metadata,
#     864         autoload_with,
#    (...)    868         resolve_fks=resolve_fks,
#     869     )
#     871 # initialize all the column, etc. objects.  done after reflection to
#     872 # allow user-overrides
# --> 874 self._init_items(
#     875     *args,
#     876     allow_replacements=extend_existing
#     877     or keep_existing
#     878     or autoload_with,
#     879     all_names={},
#     880 )
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\schema.py:234, in SchemaItem._init_items(self, *args, **kw)
#     229     raise exc.ArgumentError(
#     230         "'SchemaItem' object, such as a 'Column' or a "
#     231         f"'Constraint' expected, got {item!r}"
#     232     ) from err
#     233 else:
# --> 234     spwd(self, **kw)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\base.py:1420, in SchemaEventTarget._set_parent_with_dispatch(self, parent, **kw)
#    1416 def _set_parent_with_dispatch(
#    1417     self, parent: SchemaEventTarget, **kw: Any
#    1418 ) -> None:
#    1419     self.dispatch.before_parent_attach(self, parent)
# -> 1420     self._set_parent(parent, **kw)
#    1421     self.dispatch.after_parent_attach(self, parent)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\sqlalchemy\sql\schema.py:2360, in Column._set_parent(self, parent, all_names, allow_replacements, **kw)
#    2358 if existing_col is not self:
#    2359     if not allow_replacements:
# -> 2360         raise exc.DuplicateColumnError(
#    2361             f"A column with {conflicts_on} " f"""'{
#    2362                 self.key if conflicts_on == 'key' else self.name
#    2363             }' """ f"is already present in table '{table.name}'."
#    2364         )
#    2365     for fk in existing_col.foreign_keys:
#    2366         table.foreign_keys.remove(fk)
#
# DuplicateColumnError: A column with name 'review_rating' is already present in table 'customer'.
